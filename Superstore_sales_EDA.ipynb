# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
df=pd.read_excel('Superstore.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.read_excel('Superstore.xlsx')
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...

# %%
df.head(5)
# Out:
#   Order Date  Ship Date  Row ID         Order ID       Ship Mode Customer ID  \
# 0 2013-11-15 2013-11-20   19975  ES-2013-4954697  Standard Class    LC-17140
# 1 2014-07-11 2014-12-11   16815  ES-2014-1117053  Standard Class    LT-17110
# 2 2014-08-20 2014-08-27   12502  ES-2014-4417507  Standard Class    TC-21295
# 3 2011-11-23 2011-11-29   18925  ES-2011-3717351  Standard Class    AG-10330
# 4 2014-06-10 2014-12-10   18402  ES-2014-3993955  Standard Class    HZ-14950
#
#    Customer Name   Segment             City                       State  ...  \
# 0   Logan Currie  Consumer           Cholet            Pays de la Loire  ...
# 1   Liz Thompson  Consumer             Nice  Provence-Alpes-C™te d'Azur  ...
# 2  Toby Carlisle  Consumer  Mantes-la-Ville               Ile-de-France  ...
# 3   Alex Grayson  Consumer      Carcassonne        Languedoc-Roussillon  ...
# 4    Henia Zydlo  Consumer         Beauvais                     Picardy  ...
#
# ...

# %%
df.shape
# Out:
# (51290, 23)

# %% [markdown]
# # Find missing values

# %%
df.isnull().sum()
# Out:
# Order Date        0
# Ship Date         0
# Row ID            0
# Order ID          0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %% [markdown]
# # univariates

# %%
# missing values ko fill karna ki command
# df['coulumns name'].fillna(df['columns name'].mean().inplace=True)

# %%
df['Order Priority'].value_counts()
# Out:
# Order Priority
# Medium      29433
# High        15501
# Critical     3932
# Low          2424
# Name: count, dtype: int64

# %% [markdown]
# # order priority

# %%
#df['Order Priority'].unique()

# %%
#df['Order Priority']=df['Order Priority'].replace('Critical ','Critical')

# %%
#plt.figure)figsize=(5.3)
sns.countplot(x='Order Priority',data=df)
plt.title('count of order priority')
plt.savefig('count of order priority.jpg')
plt.show()

# %% [markdown]
# # shiping mode

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: count, dtype: int64

# %%
xaxis=df['Ship Mode'].value_counts().index
yaxis=df['Ship Mode'].value_counts().values
print(xaxis)
# Out:
# Index(['Standard Class', 'Second Class', 'First Class', 'Same Day'], dtype='object', name='Ship Mode')

# %%
plt.pie(yaxis,labels=xaxis,startangle=60,autopct='%0.2f%%')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Bivariates

# %%
sns.countplot(x='Ship Mode',data=df,hue='Category')
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# # customer segments

# %%
sns.countplot(x='Segment',data=df)
# Out:
# <Axes: xlabel='Segment', ylabel='count'>

# %% [markdown]
# # product category

# %%
sns.countplot(x='Category',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(x='Category',data=df[df['Category']=='Home Office'],hue='Sub-Category')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order Date      51290 non-null  datetime64[ns]
#  1   Ship Date       51290 non-null  datetime64[ns]
#  2   Row ID          51290 non-null  int64
#  3   Order ID        51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Market          51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Product ID      51290 non-null  object
#  14  Category        51290 non-null  object
#  15  Sub-Category    51290 non-null  object
# ...

# %%
df['order year']=df['Order Date'].dt.year

# %%
df['order year'].value_counts()
# Out:
# order year
# 2014    17531
# 2013    13799
# 2012    10962
# 2011     8998
# Name: count, dtype: int64

# %%
sns.countplot(x='order year',data=df)
# Out:
# <Axes: xlabel='order year', ylabel='count'>

# %%
sns.barplot(x='Category',y='Profit',data=df,estimator='sum')
# Out:
# <Axes: xlabel='Category', ylabel='Profit'>

# %%
# top 5 state sales
df['State'].value_counts()[:5]
# Out:
# State
# California       2001
# England          1499
# New York         1128
# Texas             985
# Ile-de-France     981
# Name: count, dtype: int64

# %%
#sns.barplot(x='Category',y='margion',data=df,estimator='sum')
